# %% [markdown]
# # Control

# %%
ctrl = np.loadtxt('3freq_control.txt')
time_ctrl = ctrl[0,:]
left_ctrl = ctrl[1,:]
right_ctrl = ctrl[2,:]
################################
f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.plot(time_ctrl, left_ctrl , label="Left channel")
ax.plot(time_ctrl, right_ctrl, label="Right channel")
ax.set_xlabel("Time (s)")
ax.set_ylabel("Amplitude")







g=left_ctrl[10000:10700]
t=time_ctrl[10000:10700]
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
ax2.set_xlabel("Frequency (Hz)")
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')


plt.show()

#Power Spectrum
power_s_ctrl=(np.abs(G))**2
plt.plot(f, power_s_ctrl)
plt.show()
#Phase thing
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
#An attempt to pull out frequency, magnitute of FT, and phase from the data
#The goal is to graph phase vs magnitute for all of the trials but I can't get the points out efficiently

freq=np.array(())
x=np.where(power_s_ctrl > 0.5e12)
freq=np.append(freq,(np.abs(f[x])))
freq=np.unique(freq)
print(freq)

mag=np.array(())
for x in range(0,700):
    for element in freq:
        if f[x]==element:
            mag=np.append(mag,(np.abs(G[x])))
print(mag)

phs=np.array(())
for x in range(0,700):
    for element in freq:
        if f[x]==element:
            phs=np.append(phs,phase[x])
            
    
print(phs)
# Out:
# [ 5859. 12033. 18333. 18396.]
# [1690439.11919206  768783.8461549   832934.70461767 1280615.74008064]
# [-1.89053375  1.25993724 -1.36876509  1.78999802]

# %%
#####################################################################################

# %% [markdown]
# # Paper Bag

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import fftpack

# %%
pb = np.loadtxt('3freq_pb.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[107000:107800]
t=time_pb[107000:107800]#Zoom in between 2.4263148755642168s and 2.444455547531052s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()


for x in range(0,800):
    for element in freq:
        if f[x]==element:
            mag=np.append(mag,(np.abs(G[x])))

for x in range(0,800):
    for element in freq:
        if f[x]==element:
            phs=np.append(phs,phase[x])
# Out:
# [27939.         27942.44126771 27941.6167534  ...  8621.84145351
#   8930.33264815  7883.25460264]
# [ 3.14159265 -3.01948726 -2.90842159 ...  0.38962577  0.02005344
#   0.00689345]

# %%
pb = np.loadtxt('3freq_pb30.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

for x in range(0,800):
    for element in freq:
        if f[x]==element:
            mag=np.append(mag,(np.abs(G[x])))

for x in range(0,800):
    for element in freq:
        if f[x]==element:
            phs=np.append(phs,phase[x])

# %%
pb = np.loadtxt('3freq_pb40.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
pb = np.loadtxt('3freq_pb50.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
pb = np.loadtxt('3freq_pb30__.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
pb = np.loadtxt('3freq_pb55__.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
pb = np.loadtxt('3freq_pb70__.txt')
time_pb = pb[0,:]
left_pb = pb[1,:]
right_pb = pb[2,:]

################################

a = plt.figure(figsize=(10,3))
ax = a.add_subplot(121)
ax2 = a.add_subplot(122)
ax.plot(time_pb, left_pb , label="Left channel")
ax.plot(time_pb, right_pb, label="Right channel")

#####################################################################################

g=left_pb[60000:60800]
t=time_pb[60000:60800]#Zoom in between 1.360550397512645s and 1.3786910694794803s
dt = 1/44100 # increment between times in time array
G = fftpack.fft(g) # FFT of g
f = fftpack.fftfreq(g.size, d=dt) # frequenies f[i] of g[i]
f = fftpack.fftshift(f) # shift frequencies from min to max 
ax2.plot(f, np.real(G), color='black', label='real part')
#ax2.plot(f, np.imag(G), color='blue', label='imaginary part')
plt.show()
g.shape

#####################################################################################

#Power Spectrum
fig = plt.figure(1)
power_s=(np.abs(G))**2
plt.plot(f, power_s)


#Phase thing
fig = plt.figure(2)
phase=np.angle(G)
plt.plot(f, phase)
plt.xlabel("Frequency [Hz]")
plt.ylabel("Angle [rad]")
plt.show()

# %%
#Plotting phs vs mag (but she doesn't work rn sadly)

fig, ax = plt.subplots(constrained_layout=True)
ax.scatter(phs, mag)
ax.set_xlabel('Angle [red]')
ax.set_ylabel('Magnitude')
ax.set_title('The Thingy')
plt.show()
