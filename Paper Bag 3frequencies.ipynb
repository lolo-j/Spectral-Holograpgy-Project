# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import fftpack 
from Functions import graph_amp_ft, find_frequency

# %% [markdown]
# # Control

# %%
ctrl = np.loadtxt('3freq_control.txt')
a,b,G,phase=graph_amp_ft(ctrl,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
#An attempt to pull out magnitute of FT, and phase from the data
#The goal is to graph phase vs magnitute for all of the trials
mag=np.array(())
phs=np.array(())
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376]
# [-1.29449496 -0.04361455 -2.23805504]

# %%
#####################################################################################

# %% [markdown]
# # Paper Bag

# %%
pb = np.loadtxt('3freq_pb.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988]

# %%
pb = np.loadtxt('3freq_pb30.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352 ]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087]

# %%
pb = np.loadtxt('3freq_pb40.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#g00d
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352  2609700.2849966  1084162.06469762 1816347.99579629]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087 -0.31519117 -2.68379592 -2.64077789]

# %%
pb = np.loadtxt('3freq_pb50.txt')
a,b,G,phase=graph_amp_ft(ctrl,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352  2609700.2849966  1084162.06469762 1816347.99579629
#  1272285.32792134  712908.32155034 1645766.04296376]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087 -0.31519117 -2.68379592 -2.64077789
#  -1.29449496 -0.04361455 -2.23805504]

# %%
pb = np.loadtxt('3freq_pb30__.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352  2609700.2849966  1084162.06469762 1816347.99579629
#  1272285.32792134  712908.32155034 1645766.04296376 2919807.85269039
#  1154511.87973333 1718905.85599194]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087 -0.31519117 -2.68379592 -2.64077789
#  -1.29449496 -0.04361455 -2.23805504 -2.75419163 -1.04368455  0.65249345]

# %%
pb = np.loadtxt('3freq_pb55__.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352  2609700.2849966  1084162.06469762 1816347.99579629
#  1272285.32792134  712908.32155034 1645766.04296376 2919807.85269039
#  1154511.87973333 1718905.85599194 3005166.4109068  1153506.18646003
#  1851407.60791313]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087 -0.31519117 -2.68379592 -2.64077789
#  -1.29449496 -0.04361455 -2.23805504 -2.75419163 -1.04368455  0.65249345
#   0.62643183 -0.14385463 -0.2884088 ]

# %%
pb = np.loadtxt('3freq_pb70__.txt')
a,b,G,phase=graph_amp_ft(pb,60000,60800) #Plots amplitude, fft, power spectrum, phase
freq,i=find_frequency(a,b)
freq=np.unique(np.abs(freq)) #Pulls out frequency from power spectrum

# %%
for element in i[3:6]:
    mag=np.append(mag,(np.abs(G[element])))
    phs=np.append(phs,(phase[element]))    
print(mag)  
print(phs)
#good
# Out:
# [1272285.32792134  712908.32155034 1645766.04296376  936538.03942994
#  1327137.17540297 2499616.98424097 2227392.76725737 1088127.19006116
#  1443810.5617352  2609700.2849966  1084162.06469762 1816347.99579629
#  1272285.32792134  712908.32155034 1645766.04296376 2919807.85269039
#  1154511.87973333 1718905.85599194 3005166.4109068  1153506.18646003
#  1851407.60791313 2519462.67976785 1133124.83984978 1746168.93998114]
# [-1.29449496 -0.04361455 -2.23805504 -1.48301723 -2.90590578 -2.40111988
#   0.45416103 -1.15840043  1.38034087 -0.31519117 -2.68379592 -2.64077789
#  -1.29449496 -0.04361455 -2.23805504 -2.75419163 -1.04368455  0.65249345
#   0.62643183 -0.14385463 -0.2884088   0.45352919 -2.79916124  2.75436432]

# %%
#Plotting phs vs mag (but she doesn't work rn sadly) update: i think she do

fig, ax = plt.subplots(constrained_layout=True)
ax.scatter(phs, mag)
ax.set_xlabel('Angle [rad]')
ax.set_ylabel('Magnitude')
ax.set_title('The Thingy')
plt.show()
